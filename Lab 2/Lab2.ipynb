# %%
from nltk.tokenize import sent_tokenize, word_tokenize

example_string = """
Muad'Dib learned rapidly because his first training was in how to learn.
And the first lesson of all was the basic trust that he could learn.
It's shocking to find how many people do not believe they can learn,
and how many more believe learning to be difficult."""

word_tokenize(example_string)
# Out:
# ["Muad'Dib",
#  'learned',
#  'rapidly',
#  'because',
#  'his',
#  'first',
#  'training',
#  'was',
#  'in',
#  'how',
#  'to',
#  'learn',
#  '.',
#  'And',
#  'the',
#  'first',
#  'lesson',
#  'of',
#  'all',
#  'was',
#  'the',
#  'basic',
#  'trust',
#  'that',
#  'he',
#  'could',
#  'learn',
#  '.',
#  'It',
#  "'s",
#  'shocking',
#  'to',
#  'find',
#  'how',
#  'many',
#  'people',
#  'do',
#  'not',
#  'believe',
#  'they',
#  'can',
#  'learn',
#  ',',
#  'and',
#  'how',
#  'many',
#  'more',
#  'believe',
#  'learning',
#  'to',
#  'be',
#  'difficult',
#  '.']

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

example_string = """
Muad'Dib learned rapidly because his first training was in how to learn.
And the first lesson of all was the basic trust that he could learn.
It's shocking to find how many people do not believe they can learn,
and how many more believe learning to be difficult."""

sent_tokenize(example_string)
# Out:
# ["\nMuad'Dib learned rapidly because his first training was in how to learn.",
#  'And the first lesson of all was the basic trust that he could learn.',
#  "It's shocking to find how many people do not believe they can learn,\nand how many more believe learning to be difficult."]

# %%
#nltk.download("stopwords")
from nltk.corpus import stopwords # Text data
from nltk.tokenize import word_tokenize

worf_quote = "Sir, I protest. I am not a merry man!"

words_in_quote = word_tokenize(worf_quote)

stop_words = set(stopwords.words("english")) # To focus on stop_words in English
filtered_list = []

# 1st way
# for word in words_in_quote:
#    if word.casefold() not in stop_words:
#         filtered_list.append(word)
        
# print(filtered_list)
        
# Alternative way using list comprehension that is more pythonic        
filtered_list = [
    word for word in words_in_quote if word.casefold() not in stop_words
]

print(filtered_list)
# Out:
# ['Sir', ',', 'protest', '.', 'merry', 'man', '!']

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

stemmer = PorterStemmer()

string_for_stemming = """
The crew of the USS Discovery discovered many discoveries.
Discovering is what explorers do."""

words = word_tokenize(string_for_stemming) # Before Stemming

stemmed_words = [stemmer.stem(word) for word in words] # Using list comprehension

stemmed_words
# Out:
# ['the',
#  'crew',
#  'of',
#  'the',
#  'uss',
#  'discoveri',
#  'discov',
#  'mani',
#  'discoveri',
#  '.',
#  'discov',
#  'is',
#  'what',
#  'explor',
#  'do',
#  '.']

# %%
import nltk
#nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
lemmatizer.lemmatize("worst",pos="a") # scarf
# Out:
# 'bad'

# %%
tag_map={
    'CC':None,
    'CD':wn.NOUN,
    'DT':wn.NOUN,
    'EX':wn.ADV,
    'FW':None,
    'IN':wn.ADV,
    'JJ':wn.ADJ,
    'JJR':wn.ADJ,
    'JJS':wn.ADJ,
    'LS':None,
    'MD':None,
    'NN':wn.NOUN,
    'NNS':wn.NOUN,
    'NNP':wn.NOUN,
    'NNPS':wn.NOUN,
    'PDT':wn.ADJ,
    'POS':None,
    'PRP':None,
    'PRP$':None,
    'RB':wn.ADV,
    'RBR':wn.ADV,
    'RBS':wn.ADV,
    'RP':wn.ADJ,
    'SYM':None,
    'TO':None,
    'UH':None,
    'VB':wn.VERB,
    'VBD':wn.VERB,
    'VBG':wn.VERB,
    'VBN':wn.VERB,
    'VBP':wn.VERB,
    'VBZ':wn.VERB,
}

# %%
tags=pos_tag(tokens)
tags

# %%
lemmatized_words = [lemmatizer.lemmatize(tag[0],pos=tag_map[tag[1]]) for tag in tags]
lemmatized_words

# %%
path = "C:\desktop\nathan" #string
print("string:",path)
# Out:
# string: C:\desktop
# athan

# %%
# Hands on
import nltk
from nltk.tokenize import RegexpTokenizer

sentence  = "Think and wonder, wonder and think."

tokenizer = nltk.RegexpTokenizer("\w+") # \w helps in extraction of alphanumeric characters only (characters from a to Z, digits from 0-9, and the underscore _ character)

new_words = tokenizer.tokenize(sentence)

print(new_words)

# or

# from nltk.tokenize import word_tokenize

# sentence  = "Think and wonder, wonder and think."

# words = nltk.word_tokenize(sentence)
# new_words= [word for word in words if word.isalnum()] # Use isalpha() to remove non alphabetic characters too.

# print(new_words)
# Out:
# ['Think', 'and', 'wonder', 'wonder', 'and', 'think']

# %%
import re

str = r"2 million monthly visits in Jan'19."

x = re.match(r"mil", str)
print(x)
# Out:
# None

# %%
import re

str = "id : 1, name : ahmed, age : 23\nid : 2,name : oamr, age : 15\nid : 3,name : mina, age : 41"

x = re.findall("age : \d+", str)
f=[re.search("\d+",s).group() for s in x]
print(f)

if(x):
    print("yes, there is at least one match")
else:
    print("No match")
# Out:
# ['23', '15', '41']
# yes, there is at least one match

# %%
import re

result = re.match('Analytics', r'Analytics Vidhya is the largest')
print(result)
# Out:
# <re.Match object; span=(0, 9), match='Analytics'>

# %%
import re

result = re.match('Analytics', r'Analytics Vidhya is the largest')
print(result.group())
# Out:
# Analytics

# %%
import re

str = r'Analytics Vidhya is the largest'

x = re.findall(r'est\b', str)

print(x)
# Out:
# ['est']

# %%
import re

str = "easy easssy eay ey"

x = re.findall("eas?y", str)
print(x)

if (x):
    print('yes, there is at least one match!')
else:
    print('No match')
# Out:
# ['easy', 'eay']
# yes, there is at least one match!

# %%
str = r'Analytics vidhya establishment is an Analytics community of India'

x = re.findall(r'\best', str)
print(x)
# Out:
# ['est']

# %%
str = r'Analytics vidhya is the largest Analytics community of India'

x = re.findall(r'est\b', str)
print(x)
# Out:
# ['est']
